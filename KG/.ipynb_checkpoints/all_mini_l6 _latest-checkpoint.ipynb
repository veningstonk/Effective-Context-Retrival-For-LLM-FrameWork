# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/squad-dataset/train.json

# %%
import pandas as pd
import numpy as np
import json
import torch
import math

# %%
file_path = "train.json"
squad_dict = {}
with open(file_path,'r') as f:
  squad_dict = json.load(f)

# %%
min_context_len = 10000;
max_context_len = 0;
average_context_size = 0;
total_number_of_context = 0;
context_greater_than_500 = 0

# %%
questionContext = {};
data = squad_dict['data']
row_Data = []  #creating list
context_index  = 0
cnt = 0
for article in data:
    for paragraph in article['paragraphs']:
        context = paragraph['context']

        context_words = context.split()
        min_context_len = min(min_context_len, len(context_words))
        max_context_len = max(max_context_len, len(context_words))
        total_number_of_context += 1
        if len(context_words) > 500:
            context_greater_than_500+=1
        
        for qa in paragraph['qas']:
            if not qa['is_impossible']:
                question = qa['question']
                for ans in qa['answers']:
                    answer = ans['text']
                    start = ans['answer_start']
                    end = start + len(answer)
                    row_Data.append(
                        {
                            'context':context,
                            'question':question,
                            'answer':answer,
                            'start':start,
                            'end':end,
                            'c_id':context_index
                        }
                    )
                    #adding question context
                    questionContext[question] = context_index
        context_index += 1

# %%
print("min_context_len : ",min_context_len)
print("max_context_len : ",max_context_len)
print("total_number_of_context : ",total_number_of_context)
print("total_number of context greater than 500 : ", context_greater_than_500)

counter = 0
for i in questionContext:
  counter+=1;
print("size of question Context : ", counter)
# Out:
# min_context_len :  20
# max_context_len :  653
# total_number_of_context :  19035
# total_number of context greater than 500 :  3
# size of question Context :  86769

# %%
row = pd.DataFrame(row_Data)

# %%
l = row['context'].tolist()
documents = row[['context','c_id']].drop_duplicates().reset_index(drop=True)
documents
# Out:
#                                                  context   c_id
# 0      Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...      0
# 1      Following the disbandment of Destiny's Child i...      1
# 2      A self-described "modern-day feminist", Beyonc...      2
# 3      Beyoncé Giselle Knowles was born in Houston, T...      3
# 4      Beyoncé attended St. Mary's Elementary School ...      4
# ...                                                  ...    ...
# 18877  Institute of Medicine, the central college of ...  18975
# 18878  Football and Cricket are the most popular spor...  18976
# 18879  The total length of roads in Nepal is recorded...  18977
# 18880  The main international airport serving Kathman...  18978
# 18881  Kathmandu Metropolitan City (KMC), in order to...  18979
#
# [18882 rows x 2 columns]

# %%
# !pip install transformers faiss-cpu datasets
# Out:
# Requirement already satisfied: transformers in /home/a.hunain/anaconda3/envs/tensorflow-gpu/lib/python3.10/site-packages (4.48.1)
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.11.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (4.8 kB)
# Requirement already satisfied: datasets in /home/a.hunain/anaconda3/envs/tensorflow-gpu/lib/python3.10/site-packages (3.6.0)
# Requirement already satisfied: filelock in /home/a.hunain/anaconda3/envs/tensorflow-gpu/lib/python3.10/site-packages (from transformers) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /home/a.hunain/anaconda3/envs/tensorflow-gpu/lib/python3.10/site-packages (from transformers) (0.28.0)
# Requirement already satisfied: numpy>=1.17 in /home/a.hunain/anaconda3/envs/tensorflow-gpu/lib/python3.10/site-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /home/a.hunain/anaconda3/envs/tensorflow-gpu/lib/python3.10/site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/a.hunain/anaconda3/envs/tensorflow-gpu/lib/python3.10/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /home/a.hunain/anaconda3/envs/tensorflow-gpu/lib/python3.10/site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /home/a.hunain/anaconda3/envs/tensorflow-gpu/lib/python3.10/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /home/a.hunain/anaconda3/envs/tensorflow-gpu/lib/python3.10/site-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /home/a.hunain/anaconda3/envs/tensorflow-gpu/lib/python3.10/site-packages (from transformers) (0.5.2)
# Requirement already satisfied: tqdm>=4.27 in /home/a.hunain/anaconda3/envs/tensorflow-gpu/lib/python3.10/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /home/a.hunain/anaconda3/envs/tensorflow-gpu/lib/python3.10/site-packages (from datasets) (19.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/a.hunain/anaconda3/envs/tensorflow-gpu/lib/python3.10/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /home/a.hunain/anaconda3/envs/tensorflow-gpu/lib/python3.10/site-packages (from datasets) (2.2.3)
# Requirement already satisfied: xxhash in /home/a.hunain/anaconda3/envs/tensorflow-gpu/lib/python3.10/site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /home/a.hunain/anaconda3/envs/tensorflow-gpu/lib/python3.10/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /home/a.hunain/anaconda3/envs/tensorflow-gpu/lib/python3.10/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2024.9.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/a.hunain/anaconda3/envs/tensorflow-gpu/lib/python3.10/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.11.11)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/a.hunain/anaconda3/envs/tensorflow-gpu/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/a.hunain/anaconda3/envs/tensorflow-gpu/lib/python3.10/site-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/a.hunain/anaconda3/envs/tensorflow-gpu/lib/python3.10/site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/a.hunain/anaconda3/envs/tensorflow-gpu/lib/python3.10/site-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/a.hunain/anaconda3/envs/tensorflow-gpu/lib/python3.10/site-packages (from requests->transformers) (2024.12.14)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/a.hunain/anaconda3/envs/tensorflow-gpu/lib/python3.10/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/a.hunain/anaconda3/envs/tensorflow-gpu/lib/python3.10/site-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/a.hunain/anaconda3/envs/tensorflow-gpu/lib/python3.10/site-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/a.hunain/anaconda3/envs/tensorflow-gpu/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/a.hunain/anaconda3/envs/tensorflow-gpu/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /home/a.hunain/anaconda3/envs/tensorflow-gpu/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/a.hunain/anaconda3/envs/tensorflow-gpu/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/a.hunain/anaconda3/envs/tensorflow-gpu/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/a.hunain/anaconda3/envs/tensorflow-gpu/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/a.hunain/anaconda3/envs/tensorflow-gpu/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/a.hunain/anaconda3/envs/tensorflow-gpu/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.18.3)
# Requirement already satisfied: six>=1.5 in /home/a.hunain/anaconda3/envs/tensorflow-gpu/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading faiss_cpu-1.11.0-cp310-cp310-manylinux_2_28_x86_64.whl (31.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.3/31.3 MB 10.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.11.0

# %%
import faiss
from transformers import AutoTokenizer , AutoModel
model_name = "sentence-transformers/all-MiniLM-L6-v2"
tokenizer = AutoTokenizer.from_pretrained(model_name)

model = AutoModel.from_pretrained(model_name)
model.eval().cuda()
# Out:
# /home/a.hunain/anaconda3/envs/tensorflow-gpu/lib/python3.10/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
#   warn(f"Failed to load image Python extension: {e}")
# 2025-06-17 12:49:33.713767: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-06-17 12:49:34.859281: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750144775.143718   32029 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750144775.272035   32029 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1750144776.137003   32029 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1750144776.137027   32029 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1750144776.137029   32029 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1750144776.137031   32029 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-06-17 12:49:36.169693: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# BertModel(
#   (embeddings): BertEmbeddings(
#     (word_embeddings): Embedding(30522, 384, padding_idx=0)
#     (position_embeddings): Embedding(512, 384)
#     (token_type_embeddings): Embedding(2, 384)
#     (LayerNorm): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder): BertEncoder(
#     (layer): ModuleList(
#       (0-5): 6 x BertLayer(
#         (attention): BertAttention(
#           (self): BertSdpaSelfAttention(
#             (query): Linear(in_features=384, out_features=384, bias=True)
#             (key): Linear(in_features=384, out_features=384, bias=True)
#             (value): Linear(in_features=384, out_features=384, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=384, out_features=384, bias=True)
#             (LayerNorm): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=384, out_features=1536, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=1536, out_features=384, bias=True)
#           (LayerNorm): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#   )
#   (pooler): BertPooler(
#     (dense): Linear(in_features=384, out_features=384, bias=True)
#     (activation): Tanh()
#   )
# )

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)

# %%
import torch.nn.functional as F
from tqdm import tqdm


# Mean Pooling Function
def mean_pooling(model_output, attention_mask):
    token_embeddings = model_output.last_hidden_state 
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    pooled = torch.sum(token_embeddings * input_mask_expanded, dim=1) / input_mask_expanded.sum(dim=1)
    return pooled

# Encode Single Batch of Texts
def encode_text(texts):
    encoded_input = tokenizer(texts, return_tensors='pt', padding=True, truncation=True, max_length=512).to(device)

    with torch.no_grad():
        model_output = model(**encoded_input)
    
    sentence_embeddings = mean_pooling(model_output, encoded_input['attention_mask'])
    sentence_embeddings = F.normalize(sentence_embeddings, p=2, dim=1)  # L2 normalize

    return sentence_embeddings.detach().cpu().numpy()


def encode_in_batches(texts, batch_size=32):
    all_embeddings = []
    for i in tqdm(range(0, len(texts), batch_size), desc="Encoding"):
        batch_texts = texts[i:i + batch_size]
        batch_embeddings = encode_text(batch_texts)
        all_embeddings.append(batch_embeddings)
    return np.vstack(all_embeddings)

# %%
texts = documents['context'].tolist()
doc_embeddings = encode_in_batches(texts, batch_size=32)
# Out:
# Encoding: 100%|███████████████████████████████| 591/591 [00:13<00:00, 42.57it/s]

# %%
dimension = doc_embeddings.shape[1]
index = faiss.IndexFlatL2(dimension)
index.add(doc_embeddings)

# %%
question = []
for keys, value in questionContext.items():
  question.append(keys)

# %%
def dcg(scores):
    """Compute Discounted Cumulative Gain"""
    return sum([rel / math.log2(idx + 2) for idx, rel in enumerate(scores)])


def compute_metrics(question, questionContext, index, k=10, max_samples=2000):
    total_correct = 0
    reciprocal_ranks = []
    ndcg_scores = []
    recall_scores = []
    precision_scores = []
    mar_scores = []

    for idx, ques in enumerate(question):
        if idx >= max_samples:
            break

        query_embedding = encode_text([ques])
        distances, indices = index.search(query_embedding, k)

        predictions = indices[0]
        actual_index = questionContext.get(ques, -1)

        # Relevance array: 1 at correct prediction position, 0 otherwise
        relevance = [1 if pred == actual_index else 0 for pred in predictions]

        # Accuracy@k
        if actual_index in predictions:
            total_correct += 1

        # MRR
        if actual_index in predictions:
            rank = list(predictions).index(actual_index)
            reciprocal_ranks.append(1.0 / (rank + 1))
        else:
            reciprocal_ranks.append(0.0)

        # NDCG
        ideal_relevance = sorted(relevance, reverse=True)
        ndcg = dcg(relevance) / dcg(ideal_relevance) if sum(ideal_relevance) > 0 else 0.0
        ndcg_scores.append(ndcg)

        # Recall@k and Precision@k
        recall = 1.0 if actual_index in predictions else 0.0
        precision = 1.0 / (list(predictions).index(actual_index) + 1) if actual_index in predictions else 0.0
        recall_scores.append(recall)
        precision_scores.append(precision)

        # MAR (Mean Average Relevance)
        mar = sum(relevance) / k
        mar_scores.append(mar)

    num_samples = min(len(question), max_samples)
    return {
        f"Accuracy@{k}": (total_correct / num_samples) * 100,
        f"MRR@{k}": np.mean(reciprocal_ranks),
        f"NDCG@{k}": np.mean(ndcg_scores),
        f"Recall@{k}": np.mean(recall_scores),
        f"Precision@{k}": np.mean(precision_scores),
        f"MAR@{k}": np.mean(mar_scores)
    }

# %%
samples = [2000, 5000, 10000, 20000, 86769]

final_result = []

for spl in samples:
    temp = []
    for k in [1, 2, 3, 4, 5, 10, 15, 20, 25, 30, 40, 50, 75, 100]:
        results = compute_metrics(
            question = question,
            questionContext=questionContext,
            index = index,
            k=k,
            max_samples=spl
        )
        temp.append(results)
        print(f"\n🔍 Top-{k} Evaluation Metrics:")
        for metric, value in results.items():
            print(f"{metric}: {value:.4f}")
    final_result.append(temp)
# Out:
# 🔍 Top-1 Evaluation Metrics:
# Accuracy@1: 57.4000
# MRR@1: 0.5740
# NDCG@1: 0.5740
# Recall@1: 0.5740
# Precision@1: 0.5740
# MAR@1: 0.5740
#
# 🔍 Top-2 Evaluation Metrics:
# Accuracy@2: 69.0000
# MRR@2: 0.6320
# NDCG@2: 0.6472
# Recall@2: 0.6900
# Precision@2: 0.6320
# MAR@2: 0.3450
#
# 🔍 Top-3 Evaluation Metrics:
# Accuracy@3: 74.9500
# MRR@3: 0.6518
# NDCG@3: 0.6769
# Recall@3: 0.7495
# Precision@3: 0.6518
# MAR@3: 0.2498
#
# 🔍 Top-4 Evaluation Metrics:
# Accuracy@4: 78.6000
# MRR@4: 0.6610
# NDCG@4: 0.6927
# Recall@4: 0.7860
# Precision@4: 0.6610
# MAR@4: 0.1965
#
# 🔍 Top-5 Evaluation Metrics:
# Accuracy@5: 81.3000
# MRR@5: 0.6664
# NDCG@5: 0.7031
# Recall@5: 0.8130
# Precision@5: 0.6664
# MAR@5: 0.1626
#
# 🔍 Top-10 Evaluation Metrics:
# Accuracy@10: 87.7500
# MRR@10: 0.6754
# NDCG@10: 0.7244
# Recall@10: 0.8775
# Precision@10: 0.6754
# MAR@10: 0.0877
#
# 🔍 Top-15 Evaluation Metrics:
# Accuracy@15: 91.0000
# MRR@15: 0.6780
# NDCG@15: 0.7330
# Recall@15: 0.9100
# Precision@15: 0.6780
# MAR@15: 0.0607
#
# 🔍 Top-20 Evaluation Metrics:
# Accuracy@20: 92.8000
# MRR@20: 0.6790
# NDCG@20: 0.7373
# Recall@20: 0.9280
# Precision@20: 0.6790
# MAR@20: 0.0464
#
# 🔍 Top-25 Evaluation Metrics:
# Accuracy@25: 93.8000
# MRR@25: 0.6794
# NDCG@25: 0.7395
# Recall@25: 0.9380
# Precision@25: 0.6794
# MAR@25: 0.0375
#
# 🔍 Top-30 Evaluation Metrics:
# Accuracy@30: 94.8500
# MRR@30: 0.6798
# NDCG@30: 0.7416
# Recall@30: 0.9485
# Precision@30: 0.6798
# MAR@30: 0.0316
#
# 🔍 Top-40 Evaluation Metrics:
# Accuracy@40: 96.2000
# MRR@40: 0.6802
# NDCG@40: 0.7442
# Recall@40: 0.9620
# Precision@40: 0.6802
# MAR@40: 0.0241
#
# 🔍 Top-50 Evaluation Metrics:
# Accuracy@50: 96.8000
# MRR@50: 0.6803
# NDCG@50: 0.7453
# Recall@50: 0.9680
# Precision@50: 0.6803
# MAR@50: 0.0194
#
# 🔍 Top-75 Evaluation Metrics:
# Accuracy@75: 97.6000
# MRR@75: 0.6805
# NDCG@75: 0.7467
# Recall@75: 0.9760
# Precision@75: 0.6805
# MAR@75: 0.0130
#
# 🔍 Top-100 Evaluation Metrics:
# Accuracy@100: 98.1500
# MRR@100: 0.6805
# NDCG@100: 0.7475
# Recall@100: 0.9815
# Precision@100: 0.6805
# MAR@100: 0.0098
#
# 🔍 Top-1 Evaluation Metrics:
# Accuracy@1: 58.2400
# MRR@1: 0.5824
# NDCG@1: 0.5824
# Recall@1: 0.5824
# Precision@1: 0.5824
# MAR@1: 0.5824
#
# 🔍 Top-2 Evaluation Metrics:
# Accuracy@2: 70.0600
# MRR@2: 0.6415
# NDCG@2: 0.6570
# Recall@2: 0.7006
# Precision@2: 0.6415
# MAR@2: 0.3503
#
# 🔍 Top-3 Evaluation Metrics:
# Accuracy@3: 76.2400
# MRR@3: 0.6621
# NDCG@3: 0.6879
# Recall@3: 0.7624
# Precision@3: 0.6621
# MAR@3: 0.2541
#
# 🔍 Top-4 Evaluation Metrics:
# Accuracy@4: 79.7000
# MRR@4: 0.6707
# NDCG@4: 0.7028
# Recall@4: 0.7970
# Precision@4: 0.6707
# MAR@4: 0.1993
#
# 🔍 Top-5 Evaluation Metrics:
# Accuracy@5: 82.3200
# MRR@5: 0.6760
# NDCG@5: 0.7129
# Recall@5: 0.8232
# Precision@5: 0.6760
# MAR@5: 0.1646
#
# 🔍 Top-10 Evaluation Metrics:
# Accuracy@10: 88.7400
# MRR@10: 0.6849
# NDCG@10: 0.7340
# Recall@10: 0.8874
# Precision@10: 0.6849
# MAR@10: 0.0887
#
# 🔍 Top-15 Evaluation Metrics:
# Accuracy@15: 91.5200
# MRR@15: 0.6871
# NDCG@15: 0.7414
# Recall@15: 0.9152
# Precision@15: 0.6871
# MAR@15: 0.0610
#
# 🔍 Top-20 Evaluation Metrics:
# Accuracy@20: 93.3200
# MRR@20: 0.6881
# NDCG@20: 0.7456
# Recall@20: 0.9332
# Precision@20: 0.6881
# MAR@20: 0.0467
#
# 🔍 Top-25 Evaluation Metrics:
# Accuracy@25: 94.2600
# MRR@25: 0.6885
# NDCG@25: 0.7477
# Recall@25: 0.9426
# Precision@25: 0.6885
# MAR@25: 0.0377
#
# 🔍 Top-30 Evaluation Metrics:
# Accuracy@30: 95.0200
# MRR@30: 0.6888
# NDCG@30: 0.7493
# Recall@30: 0.9502
# Precision@30: 0.6888
# MAR@30: 0.0317
#
# 🔍 Top-40 Evaluation Metrics:
# Accuracy@40: 96.0400
# MRR@40: 0.6891
# NDCG@40: 0.7512
# Recall@40: 0.9604
# Precision@40: 0.6891
# MAR@40: 0.0240
#
# 🔍 Top-50 Evaluation Metrics:
# Accuracy@50: 96.7000
# MRR@50: 0.6892
# NDCG@50: 0.7524
# Recall@50: 0.9670
# Precision@50: 0.6892
# MAR@50: 0.0193
#
# 🔍 Top-75 Evaluation Metrics:
# Accuracy@75: 97.6800
# MRR@75: 0.6894
# NDCG@75: 0.7541
# Recall@75: 0.9768
# Precision@75: 0.6894
# MAR@75: 0.0130
#
# 🔍 Top-100 Evaluation Metrics:
# Accuracy@100: 98.1200
# MRR@100: 0.6894
# NDCG@100: 0.7548
# Recall@100: 0.9812
# Precision@100: 0.6894
# MAR@100: 0.0098
#
# 🔍 Top-1 Evaluation Metrics:
# Accuracy@1: 41.9800
# MRR@1: 0.4198
# NDCG@1: 0.4198
# Recall@1: 0.4198
# Precision@1: 0.4198
# MAR@1: 0.4198
#
# 🔍 Top-2 Evaluation Metrics:
# Accuracy@2: 51.0300
# MRR@2: 0.4651
# NDCG@2: 0.4769
# Recall@2: 0.5103
# Precision@2: 0.4651
# MAR@2: 0.2551
#
# 🔍 Top-3 Evaluation Metrics:
# Accuracy@3: 55.9100
# MRR@3: 0.4813
# NDCG@3: 0.5013
# Recall@3: 0.5591
# Precision@3: 0.4813
# MAR@3: 0.1864
#
# 🔍 Top-4 Evaluation Metrics:
# Accuracy@4: 58.7800
# MRR@4: 0.4885
# NDCG@4: 0.5137
# Recall@4: 0.5878
# Precision@4: 0.4885
# MAR@4: 0.1469
#
# 🔍 Top-5 Evaluation Metrics:
# Accuracy@5: 60.8400
# MRR@5: 0.4926
# NDCG@5: 0.5216
# Recall@5: 0.6084
# Precision@5: 0.4926
# MAR@5: 0.1217
#
# 🔍 Top-10 Evaluation Metrics:
# Accuracy@10: 67.0400
# MRR@10: 0.5010
# NDCG@10: 0.5418
# Recall@10: 0.6704
# Precision@10: 0.5010
# MAR@10: 0.0670
#
# 🔍 Top-15 Evaluation Metrics:
# Accuracy@15: 69.8400
# MRR@15: 0.5032
# NDCG@15: 0.5492
# Recall@15: 0.6984
# Precision@15: 0.5032
# MAR@15: 0.0466
#
# 🔍 Top-20 Evaluation Metrics:
# Accuracy@20: 71.9700
# MRR@20: 0.5044
# NDCG@20: 0.5542
# Recall@20: 0.7197
# Precision@20: 0.5044
# MAR@20: 0.0360
#
# 🔍 Top-25 Evaluation Metrics:
# Accuracy@25: 73.4900
# MRR@25: 0.5051
# NDCG@25: 0.5575
# Recall@25: 0.7349
# Precision@25: 0.5051
# MAR@25: 0.0294
#
# 🔍 Top-30 Evaluation Metrics:
# Accuracy@30: 74.5500
# MRR@30: 0.5054
# NDCG@30: 0.5597
# Recall@30: 0.7455
# Precision@30: 0.5054
# MAR@30: 0.0248
#
# 🔍 Top-40 Evaluation Metrics:
# Accuracy@40: 76.4400
# MRR@40: 0.5060
# NDCG@40: 0.5634
# Recall@40: 0.7644
# Precision@40: 0.5060
# MAR@40: 0.0191
#
# 🔍 Top-50 Evaluation Metrics:
# Accuracy@50: 77.8000
# MRR@50: 0.5063
# NDCG@50: 0.5658
# Recall@50: 0.7780
# Precision@50: 0.5063
# MAR@50: 0.0156
#
# 🔍 Top-75 Evaluation Metrics:
# Accuracy@75: 80.1300
# MRR@75: 0.5067
# NDCG@75: 0.5697
# Recall@75: 0.8013
# Precision@75: 0.5067
# MAR@75: 0.0107
#
# 🔍 Top-100 Evaluation Metrics:
# Accuracy@100: 81.4800
# MRR@100: 0.5068
# NDCG@100: 0.5718
# Recall@100: 0.8148
# Precision@100: 0.5068
# MAR@100: 0.0081
#
# 🔍 Top-1 Evaluation Metrics:
# Accuracy@1: 21.0300
# MRR@1: 0.2103
# NDCG@1: 0.2103
# Recall@1: 0.2103
# Precision@1: 0.2103
# MAR@1: 0.2103
#
# 🔍 Top-2 Evaluation Metrics:
# Accuracy@2: 25.6250
# MRR@2: 0.2333
# NDCG@2: 0.2393
# Recall@2: 0.2562
# Precision@2: 0.2333
# MAR@2: 0.1281
#
# 🔍 Top-3 Evaluation Metrics:
# Accuracy@3: 28.1600
# MRR@3: 0.2417
# NDCG@3: 0.2520
# Recall@3: 0.2816
# Precision@3: 0.2417
# MAR@3: 0.0939
#
# 🔍 Top-4 Evaluation Metrics:
# Accuracy@4: 29.6800
# MRR@4: 0.2455
# NDCG@4: 0.2585
# Recall@4: 0.2968
# Precision@4: 0.2455
# MAR@4: 0.0742
#
# 🔍 Top-5 Evaluation Metrics:
# Accuracy@5: 30.7800
# MRR@5: 0.2477
# NDCG@5: 0.2628
# Recall@5: 0.3078
# Precision@5: 0.2477
# MAR@5: 0.0616
#
# 🔍 Top-10 Evaluation Metrics:
# Accuracy@10: 34.3950
# MRR@10: 0.2526
# NDCG@10: 0.2745
# Recall@10: 0.3439
# Precision@10: 0.2526
# MAR@10: 0.0344
#
# 🔍 Top-15 Evaluation Metrics:
# Accuracy@15: 36.2300
# MRR@15: 0.2540
# NDCG@15: 0.2793
# Recall@15: 0.3623
# Precision@15: 0.2540
# MAR@15: 0.0242
#
# 🔍 Top-20 Evaluation Metrics:
# Accuracy@20: 37.7200
# MRR@20: 0.2549
# NDCG@20: 0.2829
# Recall@20: 0.3772
# Precision@20: 0.2549
# MAR@20: 0.0189
#
# 🔍 Top-25 Evaluation Metrics:
# Accuracy@25: 38.9300
# MRR@25: 0.2554
# NDCG@25: 0.2855
# Recall@25: 0.3893
# Precision@25: 0.2554
# MAR@25: 0.0156
#
# 🔍 Top-30 Evaluation Metrics:
# Accuracy@30: 39.9600
# MRR@30: 0.2557
# NDCG@30: 0.2876
# Recall@30: 0.3996
# Precision@30: 0.2557
# MAR@30: 0.0133
#
# 🔍 Top-40 Evaluation Metrics:
# Accuracy@40: 41.6350
# MRR@40: 0.2562
# NDCG@40: 0.2909
# Recall@40: 0.4163
# Precision@40: 0.2562
# MAR@40: 0.0104
#
# 🔍 Top-50 Evaluation Metrics:
# Accuracy@50: 43.0600
# MRR@50: 0.2565
# NDCG@50: 0.2934
# Recall@50: 0.4306
# Precision@50: 0.2565
# MAR@50: 0.0086
#
# 🔍 Top-75 Evaluation Metrics:
# Accuracy@75: 45.5300
# MRR@75: 0.2569
# NDCG@75: 0.2976
# Recall@75: 0.4553
# Precision@75: 0.2569
# MAR@75: 0.0061
#
# 🔍 Top-100 Evaluation Metrics:
# Accuracy@100: 46.9650
# MRR@100: 0.2571
# NDCG@100: 0.2998
# Recall@100: 0.4697
# Precision@100: 0.2571
# MAR@100: 0.0047
#
# 🔍 Top-1 Evaluation Metrics:
# Accuracy@1: 4.8566
# MRR@1: 0.0486
# NDCG@1: 0.0486
# Recall@1: 0.0486
# Precision@1: 0.0486
# MAR@1: 0.0486
#
# 🔍 Top-2 Evaluation Metrics:
# Accuracy@2: 5.9261
# MRR@2: 0.0539
# NDCG@2: 0.0553
# Recall@2: 0.0593
# Precision@2: 0.0539
# MAR@2: 0.0296
#
# 🔍 Top-3 Evaluation Metrics:
# Accuracy@3: 6.5334
# MRR@3: 0.0559
# NDCG@3: 0.0584
# Recall@3: 0.0653
# Precision@3: 0.0559
# MAR@3: 0.0218
#
# 🔍 Top-4 Evaluation Metrics:
# Accuracy@4: 6.9103
# MRR@4: 0.0569
# NDCG@4: 0.0600
# Recall@4: 0.0691
# Precision@4: 0.0569
# MAR@4: 0.0173
#
# 🔍 Top-5 Evaluation Metrics:
# Accuracy@5: 7.1846
# MRR@5: 0.0574
# NDCG@5: 0.0610
# Recall@5: 0.0718
# Precision@5: 0.0574
# MAR@5: 0.0144
#
# 🔍 Top-10 Evaluation Metrics:
# Accuracy@10: 8.1504
# MRR@10: 0.0587
# NDCG@10: 0.0642
# Recall@10: 0.0815
# Precision@10: 0.0587
# MAR@10: 0.0082
#
# 🔍 Top-15 Evaluation Metrics:
# Accuracy@15: 8.7001
# MRR@15: 0.0591
# NDCG@15: 0.0656
# Recall@15: 0.0870
# Precision@15: 0.0591
# MAR@15: 0.0058
#
# 🔍 Top-20 Evaluation Metrics:
# Accuracy@20: 9.1623
# MRR@20: 0.0594
# NDCG@20: 0.0667
# Recall@20: 0.0916
# Precision@20: 0.0594
# MAR@20: 0.0046
#
# 🔍 Top-25 Evaluation Metrics:
# Accuracy@25: 9.5645
# MRR@25: 0.0596
# NDCG@25: 0.0676
# Recall@25: 0.0956
# Precision@25: 0.0596
# MAR@25: 0.0038
#
# 🔍 Top-30 Evaluation Metrics:
# Accuracy@30: 9.9333
# MRR@30: 0.0597
# NDCG@30: 0.0683
# Recall@30: 0.0993
# Precision@30: 0.0597
# MAR@30: 0.0033
#
# 🔍 Top-40 Evaluation Metrics:
# Accuracy@40: 10.5510
# MRR@40: 0.0599
# NDCG@40: 0.0695
# Recall@40: 0.1055
# Precision@40: 0.0599
# MAR@40: 0.0026
#
# 🔍 Top-50 Evaluation Metrics:
# Accuracy@50: 11.1123
# MRR@50: 0.0600
# NDCG@50: 0.0705
# Recall@50: 0.1111
# Precision@50: 0.0600
# MAR@50: 0.0022
#
# 🔍 Top-75 Evaluation Metrics:
# Accuracy@75: 12.1138
# MRR@75: 0.0602
# NDCG@75: 0.0722
# Recall@75: 0.1211
# Precision@75: 0.0602
# MAR@75: 0.0016
#
# 🔍 Top-100 Evaluation Metrics:
# Accuracy@100: 12.7718
# MRR@100: 0.0603
# NDCG@100: 0.0732
# Recall@100: 0.1277
# Precision@100: 0.0603
# MAR@100: 0.0013

# %%
for result in final_result:
    print("\n")
    print(result)
    print("\n")
# Out:
# [{'Accuracy@1': 57.4, 'MRR@1': np.float64(0.574), 'NDCG@1': np.float64(0.574), 'Recall@1': np.float64(0.574), 'Precision@1': np.float64(0.574), 'MAR@1': np.float64(0.574)}, {'Accuracy@2': 69.0, 'MRR@2': np.float64(0.632), 'NDCG@2': np.float64(0.647187851414289), 'Recall@2': np.float64(0.69), 'Precision@2': np.float64(0.632), 'MAR@2': np.float64(0.345)}, {'Accuracy@3': 74.95, 'MRR@3': np.float64(0.6518333333333334), 'NDCG@3': np.float64(0.6769378514142891), 'Recall@3': np.float64(0.7495), 'Precision@3': np.float64(0.6518333333333334), 'MAR@3': np.float64(0.24983333333333332)}, {'Accuracy@4': 78.60000000000001, 'MRR@4': np.float64(0.6609583333333334), 'NDCG@4': np.float64(0.692657545783968), 'Recall@4': np.float64(0.786), 'Precision@4': np.float64(0.6609583333333334), 'MAR@4': np.float64(0.1965)}, {'Accuracy@5': 81.3, 'MRR@5': np.float64(0.6663583333333334), 'NDCG@5': np.float64(0.7031025715793006), 'Recall@5': np.float64(0.813), 'Precision@5': np.float64(0.6663583333333334), 'MAR@5': np.float64(0.1626)}, {'Accuracy@10': 87.75, 'MRR@10': np.float64(0.6754265873015872), 'NDCG@10': np.float64(0.7244162015386497), 'Recall@10': np.float64(0.8775), 'Precision@10': np.float64(0.6754265873015872), 'MAR@10': np.float64(0.08775)}, {'Accuracy@15': 91.0, 'MRR@15': np.float64(0.6779783688533688), 'NDCG@15': np.float64(0.7330075068305753), 'Recall@15': np.float64(0.91), 'Precision@15': np.float64(0.6779783688533688), 'MAR@15': np.float64(0.06066666666666666)}, {'Accuracy@20': 92.80000000000001, 'MRR@20': np.float64(0.6790039514987077), 'NDCG@20': np.float64(0.737278166939137), 'Recall@20': np.float64(0.928), 'Precision@20': np.float64(0.6790039514987077), 'MAR@20': np.float64(0.046400000000000004)}, {'Accuracy@25': 93.8, 'MRR@25': np.float64(0.6794469253364641), 'NDCG@25': np.float64(0.7394710695189224), 'Recall@25': np.float64(0.938), 'Precision@25': np.float64(0.6794469253364641), 'MAR@25': np.float64(0.03752)}, {'Accuracy@30': 94.85, 'MRR@30': np.float64(0.6798205050453887), 'NDCG@30': np.float64(0.7416296841425308), 'Recall@30': np.float64(0.9485), 'Precision@30': np.float64(0.6798205050453887), 'MAR@30': np.float64(0.03161666666666666)}, {'Accuracy@40': 96.2, 'MRR@40': np.float64(0.6802034581108397), 'NDCG@40': np.float64(0.7442347559487758), 'Recall@40': np.float64(0.962), 'Precision@40': np.float64(0.6802034581108397), 'MAR@40': np.float64(0.024050000000000005)}, {'Accuracy@50': 96.8, 'MRR@50': np.float64(0.6803413789290305), 'NDCG@50': np.float64(0.7453302141928108), 'Recall@50': np.float64(0.968), 'Precision@50': np.float64(0.6803413789290305), 'MAR@50': np.float64(0.01936)}, {'Accuracy@75': 97.6, 'MRR@75': np.float64(0.6804670568255853), 'NDCG@75': np.float64(0.7466589746531479), 'Recall@75': np.float64(0.976), 'Precision@75': np.float64(0.6804670568255853), 'MAR@75': np.float64(0.013013333333333333)}, {'Accuracy@100': 98.15, 'MRR@100': np.float64(0.6805308143264678), 'NDCG@100': np.float64(0.7475118678406273), 'Recall@100': np.float64(0.9815), 'Precision@100': np.float64(0.6805308143264678), 'MAR@100': np.float64(0.009815)}]
#
#
#
#
# [{'Accuracy@1': 58.24, 'MRR@1': np.float64(0.5824), 'NDCG@1': np.float64(0.5824), 'Recall@1': np.float64(0.5824), 'Precision@1': np.float64(0.5824), 'MAR@1': np.float64(0.5824)}, {'Accuracy@2': 70.06, 'MRR@2': np.float64(0.6415), 'NDCG@2': np.float64(0.6569758968721463), 'Recall@2': np.float64(0.7006), 'Precision@2': np.float64(0.6415), 'MAR@2': np.float64(0.3503)}, {'Accuracy@3': 76.24, 'MRR@3': np.float64(0.6621), 'NDCG@3': np.float64(0.6878758968721463), 'Recall@3': np.float64(0.7624), 'Precision@3': np.float64(0.6621), 'MAR@3': np.float64(0.2541333333333333)}, {'Accuracy@4': 79.7, 'MRR@4': np.float64(0.67075), 'NDCG@4': np.float64(0.7027773057814858), 'Recall@4': np.float64(0.797), 'Precision@4': np.float64(0.67075), 'MAR@4': np.float64(0.19925)}, {'Accuracy@5': 82.32000000000001, 'MRR@5': np.float64(0.67599), 'NDCG@5': np.float64(0.7129128493310307), 'Recall@5': np.float64(0.8232), 'Precision@5': np.float64(0.67599), 'MAR@5': np.float64(0.16463999999999995)}, {'Accuracy@10': 88.74, 'MRR@10': np.float64(0.6848761111111111), 'NDCG@10': np.float64(0.7339908236589194), 'Recall@10': np.float64(0.8874), 'Precision@10': np.float64(0.6848761111111111), 'MAR@10': np.float64(0.08873999999999999)}, {'Accuracy@15': 91.52, 'MRR@15': np.float64(0.68708724997225), 'NDCG@15': np.float64(0.741373504725637), 'Recall@15': np.float64(0.9152), 'Precision@15': np.float64(0.68708724997225), 'MAR@15': np.float64(0.06101333333333332)}, {'Accuracy@20': 93.32000000000001, 'MRR@20': np.float64(0.6881036319811938), 'NDCG@20': np.float64(0.7456315340807347), 'Recall@20': np.float64(0.9332), 'Precision@20': np.float64(0.6881036319811938), 'MAR@20': np.float64(0.04665999999999999)}, {'Accuracy@25': 94.26, 'MRR@25': np.float64(0.6885188232102546), 'NDCG@25': np.float64(0.7476908818885161), 'Recall@25': np.float64(0.9426), 'Precision@25': np.float64(0.6885188232102546), 'MAR@25': np.float64(0.037704)}, {'Accuracy@30': 95.02000000000001, 'MRR@30': np.float64(0.688792611822664), 'NDCG@30': np.float64(0.7492589002664437), 'Recall@30': np.float64(0.9502), 'Precision@30': np.float64(0.688792611822664), 'MAR@30': np.float64(0.03167333333333334)}, {'Accuracy@40': 96.04, 'MRR@40': np.float64(0.6890839378555933), 'NDCG@40': np.float64(0.7512306998226636), 'Recall@40': np.float64(0.9604), 'Precision@40': np.float64(0.6890839378555933), 'MAR@40': np.float64(0.024009999999999997)}, {'Accuracy@50': 96.7, 'MRR@50': np.float64(0.689232604301387), 'NDCG@50': np.float64(0.75242941259464), 'Recall@50': np.float64(0.967), 'Precision@50': np.float64(0.689232604301387), 'MAR@50': np.float64(0.01934)}, {'Accuracy@75': 97.68, 'MRR@75': np.float64(0.6893933291761547), 'NDCG@75': np.float64(0.7540740033088094), 'Recall@75': np.float64(0.9768), 'Precision@75': np.float64(0.6893933291761547), 'MAR@75': np.float64(0.013024)}, {'Accuracy@100': 98.11999999999999, 'MRR@100': np.float64(0.6894439970852956), 'NDCG@100': np.float64(0.7547551763076644), 'Recall@100': np.float64(0.9812), 'Precision@100': np.float64(0.6894439970852956), 'MAR@100': np.float64(0.009812000000000001)}]
#
#
#
#
# [{'Accuracy@1': 41.980000000000004, 'MRR@1': np.float64(0.4198), 'NDCG@1': np.float64(0.4198), 'Recall@1': np.float64(0.4198), 'Precision@1': np.float64(0.4198), 'MAR@1': np.float64(0.4198)}, {'Accuracy@2': 51.03, 'MRR@2': np.float64(0.46505), 'NDCG@2': np.float64(0.47689914269821704), 'Recall@2': np.float64(0.5103), 'Precision@2': np.float64(0.46505), 'MAR@2': np.float64(0.25515)}, {'Accuracy@3': 55.910000000000004, 'MRR@3': np.float64(0.48131666666666667), 'NDCG@3': np.float64(0.5012991426982171), 'Recall@3': np.float64(0.5591), 'Precision@3': np.float64(0.48131666666666667), 'MAR@3': np.float64(0.18636666666666665)}, {'Accuracy@4': 58.78, 'MRR@4': np.float64(0.4884916666666667), 'NDCG@4': np.float64(0.5136595599149233), 'Recall@4': np.float64(0.5878), 'Precision@4': np.float64(0.4884916666666667), 'MAR@4': np.float64(0.14695)}, {'Accuracy@5': 60.84, 'MRR@5': np.float64(0.4926116666666666), 'NDCG@5': np.float64(0.5216287277439549), 'Recall@5': np.float64(0.6084), 'Precision@5': np.float64(0.4926116666666666), 'MAR@5': np.float64(0.12168000000000002)}, {'Accuracy@10': 67.04, 'MRR@10': np.float64(0.5009785714285714), 'NDCG@10': np.float64(0.541768449866014), 'Recall@10': np.float64(0.6704), 'Precision@10': np.float64(0.5009785714285714), 'MAR@10': np.float64(0.06704)}, {'Accuracy@15': 69.84, 'MRR@15': np.float64(0.5031933999334), 'NDCG@15': np.float64(0.5491898722423854), 'Recall@15': np.float64(0.6984), 'Precision@15': np.float64(0.5031933999334), 'MAR@15': np.float64(0.04656)}, {'Accuracy@20': 71.97, 'MRR@20': np.float64(0.5043916352275176), 'NDCG@20': np.float64(0.554222372954225), 'Recall@20': np.float64(0.7197), 'Precision@20': np.float64(0.5043916352275176), 'MAR@20': np.float64(0.035985)}, {'Accuracy@25': 73.49, 'MRR@25': np.float64(0.5050521042657257), 'NDCG@25': np.float64(0.5575360813827731), 'Recall@25': np.float64(0.7349), 'Precision@25': np.float64(0.5050521042657257), 'MAR@25': np.float64(0.029396)}, {'Accuracy@30': 74.55000000000001, 'MRR@30': np.float64(0.5054332452001425), 'NDCG@30': np.float64(0.5597219065642833), 'Recall@30': np.float64(0.7455), 'Precision@30': np.float64(0.5054332452001425), 'MAR@30': np.float64(0.024849999999999997)}, {'Accuracy@40': 76.44, 'MRR@40': np.float64(0.5059713478612583), 'NDCG@40': np.float64(0.5633724585787344), 'Recall@40': np.float64(0.7644), 'Precision@40': np.float64(0.5059713478612583), 'MAR@40': np.float64(0.019110000000000002)}, {'Accuracy@50': 77.8, 'MRR@50': np.float64(0.5062744484927711), 'NDCG@50': np.float64(0.5658358174792554), 'Recall@50': np.float64(0.778), 'Precision@50': np.float64(0.5062744484927711), 'MAR@50': np.float64(0.01556)}, {'Accuracy@75': 80.13, 'MRR@75': np.float64(0.506656719088444), 'NDCG@75': np.float64(0.5697462700379923), 'Recall@75': np.float64(0.8013), 'Precision@75': np.float64(0.506656719088444), 'MAR@75': np.float64(0.010684)}, {'Accuracy@100': 81.47999999999999, 'MRR@100': np.float64(0.5068138727720422), 'NDCG@100': np.float64(0.5718412312531382), 'Recall@100': np.float64(0.8148), 'Precision@100': np.float64(0.5068138727720422), 'MAR@100': np.float64(0.008147999999999999)}]
#
#
#
#
# [{'Accuracy@1': 21.029999999999998, 'MRR@1': np.float64(0.2103), 'NDCG@1': np.float64(0.2103), 'Recall@1': np.float64(0.2103), 'Precision@1': np.float64(0.2103), 'MAR@1': np.float64(0.2103)}, {'Accuracy@2': 25.624999999999996, 'MRR@2': np.float64(0.233275), 'NDCG@2': np.float64(0.2392912221766085), 'Recall@2': np.float64(0.25625), 'Precision@2': np.float64(0.233275), 'MAR@2': np.float64(0.128125)}, {'Accuracy@3': 28.16, 'MRR@3': np.float64(0.241725), 'NDCG@3': np.float64(0.2519662221766085), 'Recall@3': np.float64(0.2816), 'Precision@3': np.float64(0.241725), 'MAR@3': np.float64(0.09386666666666667)}, {'Accuracy@4': 29.68, 'MRR@4': np.float64(0.245525), 'NDCG@4': np.float64(0.258512505859324), 'Recall@4': np.float64(0.2968), 'Precision@4': np.float64(0.245525), 'MAR@4': np.float64(0.0742)}, {'Accuracy@5': 30.78, 'MRR@5': np.float64(0.24772499999999995), 'NDCG@5': np.float64(0.262767886738904), 'Recall@5': np.float64(0.3078), 'Precision@5': np.float64(0.24772499999999995), 'MAR@5': np.float64(0.061560000000000004)}, {'Accuracy@10': 34.394999999999996, 'MRR@10': np.float64(0.2525696626984127), 'NDCG@10': np.float64(0.27447719365019774), 'Recall@10': np.float64(0.34395), 'Precision@10': np.float64(0.2525696626984127), 'MAR@10': np.float64(0.034395)}, {'Accuracy@15': 36.230000000000004, 'MRR@15': np.float64(0.25401572247197246), 'NDCG@15': np.float64(0.27933450243342633), 'Recall@15': np.float64(0.3623), 'Precision@15': np.float64(0.25401572247197246), 'MAR@15': np.float64(0.02415333333333333)}, {'Accuracy@20': 37.72, 'MRR@20': np.float64(0.2548522044551166), 'NDCG@20': np.float64(0.28285251027732045), 'Recall@20': np.float64(0.3772), 'Precision@20': np.float64(0.2548522044551166), 'MAR@20': np.float64(0.018860000000000002)}, {'Accuracy@25': 38.93, 'MRR@25': np.float64(0.25537883738378214), 'NDCG@25': np.float64(0.28549168233585476), 'Recall@25': np.float64(0.3893), 'Precision@25': np.float64(0.25537883738378214), 'MAR@25': np.float64(0.015571999999999999)}, {'Accuracy@30': 39.96, 'MRR@30': np.float64(0.25574831828283207), 'NDCG@30': np.float64(0.28761421109973856), 'Recall@30': np.float64(0.3996), 'Precision@30': np.float64(0.25574831828283207), 'MAR@30': np.float64(0.013319999999999997)}, {'Accuracy@40': 41.635, 'MRR@40': np.float64(0.25622711408580257), 'NDCG@40': np.float64(0.2908530420939932), 'Recall@40': np.float64(0.41635), 'Precision@40': np.float64(0.25622711408580257), 'MAR@40': np.float64(0.010408750000000001)}, {'Accuracy@50': 43.059999999999995, 'MRR@50': np.float64(0.25654280371373345), 'NDCG@50': np.float64(0.2934301815093183), 'Recall@50': np.float64(0.4306), 'Precision@50': np.float64(0.25654280371373345), 'MAR@50': np.float64(0.008612)}, {'Accuracy@75': 45.53, 'MRR@75': np.float64(0.25694807974851985), 'NDCG@75': np.float64(0.29757578639241267), 'Recall@75': np.float64(0.4553), 'Precision@75': np.float64(0.25694807974851985), 'MAR@75': np.float64(0.006070666666666666)}, {'Accuracy@100': 46.965, 'MRR@100': np.float64(0.25711432060736744), 'NDCG@100': np.float64(0.2998002217619373), 'Recall@100': np.float64(0.46965), 'Precision@100': np.float64(0.25711432060736744), 'MAR@100': np.float64(0.004696499999999999)}]
#
#
#
#
# [{'Accuracy@1': 4.856573200106029, 'MRR@1': np.float64(0.048565732001060284), 'NDCG@1': np.float64(0.048565732001060284), 'Recall@1': np.float64(0.048565732001060284), 'Precision@1': np.float64(0.048565732001060284), 'MAR@1': np.float64(0.048565732001060284)}, {'Accuracy@2': 5.926079590637209, 'MRR@2': np.float64(0.05391326395371619), 'NDCG@2': np.float64(0.055313566035269664), 'Recall@2': np.float64(0.059260795906372093), 'Precision@2': np.float64(0.05391326395371619), 'MAR@2': np.float64(0.029630397953186047)}, {'Accuracy@3': 6.533439361984119, 'MRR@3': np.float64(0.055937796524872546), 'NDCG@3': np.float64(0.058350364892004215), 'Recall@3': np.float64(0.06533439361984118), 'Precision@3': np.float64(0.055937796524872546), 'MAR@3': np.float64(0.02177813120661373)}, {'Accuracy@4': 6.910302066406206, 'MRR@4': np.float64(0.056879953285927765), 'NDCG@4': np.float64(0.05997342421607154), 'Recall@4': np.float64(0.06910302066406206), 'Precision@4': np.float64(0.056879953285927765), 'MAR@4': np.float64(0.017275755166015514)}, {'Accuracy@5': 7.184593576046745, 'MRR@5': np.float64(0.05742853630520885), 'NDCG@5': np.float64(0.061034528621121985), 'Recall@5': np.float64(0.07184593576046745), 'Precision@5': np.float64(0.05742853630520885), 'MAR@5': np.float64(0.01436918715209349)}, {'Accuracy@10': 8.150376286461755, 'MRR@10': np.float64(0.05871619627886267), 'NDCG@10': np.float64(0.06415607656783856), 'Recall@10': np.float64(0.08150376286461755), 'Precision@10': np.float64(0.05871619627886267), 'MAR@10': np.float64(0.008150376286461756)}, {'Accuracy@15': 8.700111791077457, 'MRR@15': np.float64(0.059148154536772586), 'NDCG@15': np.float64(0.06560975894128997), 'Recall@15': np.float64(0.08700111791077458), 'Precision@15': np.float64(0.059148154536772586), 'MAR@15': np.float64(0.005800074527384972)}, {'Accuracy@20': 9.16225841026173, 'MRR@20': np.float64(0.059406821782512574), 'NDCG@20': np.float64(0.06669985051110103), 'Recall@20': np.float64(0.0916225841026173), 'Precision@20': np.float64(0.059406821782512574), 'MAR@20': np.float64(0.004581129205130865)}, {'Accuracy@25': 9.564475792045545, 'MRR@25': np.float64(0.059581670109162765), 'NDCG@25': np.float64(0.06757683108720042), 'Recall@25': np.float64(0.09564475792045546), 'Precision@25': np.float64(0.059581670109162765), 'MAR@25': np.float64(0.0038257903168182187)}, {'Accuracy@30': 9.933271099125264, 'MRR@30': np.float64(0.05971376603953563), 'NDCG@30': np.float64(0.068336488403724), 'Recall@30': np.float64(0.09933271099125264), 'Precision@30': np.float64(0.05971376603953563), 'MAR@30': np.float64(0.0033110903663750866)}, {'Accuracy@40': 10.55100323848379, 'MRR@40': np.float64(0.05988930413048089), 'NDCG@40': np.float64(0.06952903869838525), 'Recall@40': np.float64(0.1055100323848379), 'Precision@40': np.float64(0.05988930413048089), 'MAR@40': np.float64(0.0026377508096209487)}, {'Accuracy@50': 11.112263596445736, 'MRR@50': np.float64(0.06001351633172203), 'NDCG@50': np.float64(0.07054382522906197), 'Recall@50': np.float64(0.11112263596445736), 'Precision@50': np.float64(0.06001351633172203), 'MAR@50': np.float64(0.002222452719289147)}, {'Accuracy@75': 12.113773352234093, 'MRR@75': np.float64(0.0601770766544506), 'NDCG@75': np.float64(0.0722228876295469), 'Recall@75': np.float64(0.12113773352234093), 'Precision@75': np.float64(0.0601770766544506), 'MAR@75': np.float64(0.0016151697802978795)}, {'Accuracy@100': 12.771842478304462, 'MRR@100': np.float64(0.06025268519149665), 'NDCG@100': np.float64(0.07324112790056538), 'Recall@100': np.float64(0.12771842478304463), 'Precision@100': np.float64(0.06025268519149665), 'MAR@100': np.float64(0.001277184247830446)}]

# %%
# saving Data for further calculation
with open("final_result.json", "w") as f:
    json.dump(final_result, f)
